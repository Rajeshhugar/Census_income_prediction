# %%
import pandas as pd
import pymongo

# %%
client=pymongo.MongoClient("mongodb://localhost:27017")
client
# Out:
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
df= pd.read_csv("Data\Processed_data.csv")
data=df.to_dict(orient="records")

# %%
data
# Out:
# [{'age': 39.0,
#   'workclass': 6,
#   'fnlwgt': 77516.0,
#   'education-num': 13.0,
#   'marital-status': 4,
#   'occupation': 0,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 2174.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 50.0,
#   'workclass': 5,
#   'fnlwgt': 83311.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 13.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 38.0,
#   'workclass': 3,
#   'fnlwgt': 215646.0,
#   'education-num': 9.0,
#   'marital-status': 0,
#   'occupation': 5,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 53.0,
#   'workclass': 3,
#   'fnlwgt': 234721.0,
#   'education-num': 7.0,
#   'marital-status': 2,
#   'occupation': 5,
#   'relationship': 0,
#   'race': 2,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 28.0,
#   'workclass': 3,
#   'fnlwgt': 338409.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 5,
#   'race': 2,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 4,
#   'class': 0},
#  {'age': 37.0,
#   'workclass': 3,
#   'fnlwgt': 284582.0,
#   'education-num': 14.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 5,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 49.0,
#   'workclass': 3,
#   'fnlwgt': 160187.0,
#   'education-num': 5.0,
#   'marital-status': 3,
#   'occupation': 7,
#   'relationship': 1,
#   'race': 2,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 16.0,
#   'native-country': 22,
#   'class': 0},
#  {'age': 52.0,
#   'workclass': 5,
#   'fnlwgt': 209642.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 45.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 31.0,
#   'workclass': 3,
#   'fnlwgt': 45781.0,
#   'education-num': 14.0,
#   'marital-status': 4,
#   'occupation': 9,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 14084.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 50.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 42.0,
#   'workclass': 3,
#   'fnlwgt': 159449.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 5178.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 37.0,
#   'workclass': 3,
#   'fnlwgt': 280464.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 0,
#   'race': 2,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 80.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 30.0,
#   'workclass': 6,
#   'fnlwgt': 141297.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 0,
#   'race': 1,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 18,
#   'class': 1},
#  {'age': 23.0,
#   'workclass': 3,
#   'fnlwgt': 122272.0,
#   'education-num': 13.0,
#   'marital-status': 4,
#   'occupation': 0,
#   'relationship': 3,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 30.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 32.0,
#   'workclass': 3,
#   'fnlwgt': 205019.0,
#   'education-num': 12.0,
#   'marital-status': 4,
#   'occupation': 11,
#   'relationship': 1,
#   'race': 2,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 50.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 40.0,
#   'workclass': 3,
#   'fnlwgt': 121772.0,
#   'education-num': 11.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 1,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 41,
#   'class': 1},
#  {'age': 34.0,
#   'workclass': 3,
#   'fnlwgt': 245487.0,
#   'education-num': 4.0,
#   'marital-status': 2,
#   'occupation': 13,
#   'relationship': 0,
#   'race': 0,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 45.0,
#   'native-country': 25,
#   'class': 0},
#  {'age': 25.0,
#   'workclass': 5,
#   'fnlwgt': 176756.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 4,
#   'relationship': 3,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 35.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 32.0,
#   'workclass': 3,
#   'fnlwgt': 186824.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 6,
#   'relationship': 4,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 38.0,
#   'workclass': 3,
#   'fnlwgt': 28887.0,
#   'education-num': 7.0,
#   'marital-status': 2,
#   'occupation': 11,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 50.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 43.0,
#   'workclass': 5,
#   'fnlwgt': 292175.0,
#   'education-num': 14.0,
#   'marital-status': 0,
#   'occupation': 3,
#   'relationship': 4,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 45.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 40.0,
#   'workclass': 3,
#   'fnlwgt': 193524.0,
#   'education-num': 16.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 60.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 54.0,
#   'workclass': 3,
#   'fnlwgt': 302146.0,
#   'education-num': 9.0,
#   'marital-status': 5,
#   'occupation': 7,
#   'relationship': 4,
#   'race': 2,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 20.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 35.0,
#   'workclass': 0,
#   'fnlwgt': 76845.0,
#   'education-num': 5.0,
#   'marital-status': 2,
#   'occupation': 4,
#   'relationship': 0,
#   'race': 2,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 43.0,
#   'workclass': 3,
#   'fnlwgt': 117037.0,
#   'education-num': 7.0,
#   'marital-status': 2,
#   'occupation': 13,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 2042.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 59.0,
#   'workclass': 3,
#   'fnlwgt': 109015.0,
#   'education-num': 9.0,
#   'marital-status': 0,
#   'occupation': 12,
#   'relationship': 4,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 56.0,
#   'workclass': 1,
#   'fnlwgt': 216851.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 12,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 19.0,
#   'workclass': 3,
#   'fnlwgt': 168294.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 2,
#   'relationship': 3,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 54.0,
#   'workclass': 8,
#   'fnlwgt': 180211.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 14,
#   'relationship': 0,
#   'race': 1,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 60.0,
#   'native-country': 34,
#   'class': 1},
#  {'age': 39.0,
#   'workclass': 3,
#   'fnlwgt': 367260.0,
#   'education-num': 9.0,
#   'marital-status': 0,
#   'occupation': 3,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 80.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 49.0,
#   'workclass': 3,
#   'fnlwgt': 193366.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 23.0,
#   'workclass': 1,
#   'fnlwgt': 190709.0,
#   'education-num': 12.0,
#   'marital-status': 4,
#   'occupation': 10,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 52.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 20.0,
#   'workclass': 3,
#   'fnlwgt': 266015.0,
#   'education-num': 10.0,
#   'marital-status': 4,
#   'occupation': 11,
#   'relationship': 3,
#   'race': 2,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 44.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 45.0,
#   'workclass': 3,
#   'fnlwgt': 386940.0,
#   'education-num': 13.0,
#   'marital-status': 0,
#   'occupation': 3,
#   'relationship': 3,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 1408.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 30.0,
#   'workclass': 0,
#   'fnlwgt': 59951.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 0,
#   'relationship': 3,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 22.0,
#   'workclass': 6,
#   'fnlwgt': 311512.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 7,
#   'relationship': 0,
#   'race': 2,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 15.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 48.0,
#   'workclass': 3,
#   'fnlwgt': 242406.0,
#   'education-num': 7.0,
#   'marital-status': 4,
#   'occupation': 6,
#   'relationship': 4,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 32,
#   'class': 0},
#  {'age': 21.0,
#   'workclass': 3,
#   'fnlwgt': 197200.0,
#   'education-num': 10.0,
#   'marital-status': 4,
#   'occupation': 6,
#   'relationship': 3,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 19.0,
#   'workclass': 3,
#   'fnlwgt': 544091.0,
#   'education-num': 9.0,
#   'marital-status': 1,
#   'occupation': 0,
#   'relationship': 5,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 25.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 31.0,
#   'workclass': 3,
#   'fnlwgt': 84154.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 11,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 38.0,
#   'native-country': 41,
#   'class': 1},
#  {'age': 48.0,
#   'workclass': 5,
#   'fnlwgt': 265477.0,
#   'education-num': 12.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 31.0,
#   'workclass': 3,
#   'fnlwgt': 507875.0,
#   'education-num': 5.0,
#   'marital-status': 2,
#   'occupation': 6,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 43.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 53.0,
#   'workclass': 5,
#   'fnlwgt': 88506.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 24.0,
#   'workclass': 3,
#   'fnlwgt': 172987.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 12,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 50.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 49.0,
#   'workclass': 3,
#   'fnlwgt': 94638.0,
#   'education-num': 9.0,
#   'marital-status': 5,
#   'occupation': 0,
#   'relationship': 4,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 25.0,
#   'workclass': 3,
#   'fnlwgt': 289980.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 5,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 35.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 57.0,
#   'workclass': 0,
#   'fnlwgt': 337895.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 0,
#   'race': 2,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 53.0,
#   'workclass': 3,
#   'fnlwgt': 144361.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 6,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 38.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 44.0,
#   'workclass': 3,
#   'fnlwgt': 128354.0,
#   'education-num': 14.0,
#   'marital-status': 0,
#   'occupation': 3,
#   'relationship': 4,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 41.0,
#   'workclass': 6,
#   'fnlwgt': 101603.0,
#   'education-num': 11.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 29.0,
#   'workclass': 3,
#   'fnlwgt': 271466.0,
#   'education-num': 11.0,
#   'marital-status': 4,
#   'occupation': 9,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 43.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 25.0,
#   'workclass': 3,
#   'fnlwgt': 32275.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 5,
#   'race': 3,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 18.0,
#   'workclass': 3,
#   'fnlwgt': 226956.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 7,
#   'relationship': 3,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 30.0,
#   'native-country': 41,
#   'class': 0},
#  {'age': 47.0,
#   'workclass': 3,
#   'fnlwgt': 51835.0,
#   'education-num': 15.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 5,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 1902.0,
#   'hours-per-week': 60.0,
#   'native-country': 15,
#   'class': 1},
#  {'age': 50.0,
#   'workclass': 0,
#   'fnlwgt': 251585.0,
#   'education-num': 13.0,
#   'marital-status': 0,
#   'occupation': 3,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 55.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 47.0,
#   'workclass': 4,
#   'fnlwgt': 109832.0,
#   'education-num': 9.0,
#   'marital-status': 0,
#   'occupation': 3,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 60.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 43.0,
#   'workclass': 3,
#   'fnlwgt': 237993.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 12,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 46.0,
#   'workclass': 3,
#   'fnlwgt': 216666.0,
#   'education-num': 3.0,
#   'marital-status': 2,
#   'occupation': 6,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 25,
#   'class': 0},
#  {'age': 35.0,
#   'workclass': 3,
#   'fnlwgt': 56352.0,
#   'education-num': 11.0,
#   'marital-status': 2,
#   'occupation': 7,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 32,
#   'class': 0},
#  {'age': 41.0,
#   'workclass': 3,
#   'fnlwgt': 147372.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 0,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 48.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 30.0,
#   'workclass': 3,
#   'fnlwgt': 188146.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 6,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 5013.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 30.0,
#   'workclass': 3,
#   'fnlwgt': 59496.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 11,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 2407.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 32.0,
#   'workclass': 8,
#   'fnlwgt': 293936.0,
#   'education-num': 4.0,
#   'marital-status': 3,
#   'occupation': 14,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 41,
#   'class': 0},
#  {'age': 48.0,
#   'workclass': 3,
#   'fnlwgt': 149640.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 13,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 42.0,
#   'workclass': 3,
#   'fnlwgt': 116632.0,
#   'education-num': 16.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 45.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 29.0,
#   'workclass': 3,
#   'fnlwgt': 105598.0,
#   'education-num': 10.0,
#   'marital-status': 0,
#   'occupation': 12,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 58.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 36.0,
#   'workclass': 3,
#   'fnlwgt': 155537.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 28.0,
#   'workclass': 3,
#   'fnlwgt': 183175.0,
#   'education-num': 10.0,
#   'marital-status': 0,
#   'occupation': 0,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 53.0,
#   'workclass': 3,
#   'fnlwgt': 169846.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 0,
#   'relationship': 5,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 49.0,
#   'workclass': 4,
#   'fnlwgt': 191681.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 50.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 25.0,
#   'workclass': 8,
#   'fnlwgt': 200681.0,
#   'education-num': 10.0,
#   'marital-status': 4,
#   'occupation': 14,
#   'relationship': 3,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 19.0,
#   'workclass': 3,
#   'fnlwgt': 101509.0,
#   'education-num': 10.0,
#   'marital-status': 4,
#   'occupation': 9,
#   'relationship': 3,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 32.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 31.0,
#   'workclass': 3,
#   'fnlwgt': 309974.0,
#   'education-num': 13.0,
#   'marital-status': 5,
#   'occupation': 11,
#   'relationship': 3,
#   'race': 2,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 29.0,
#   'workclass': 5,
#   'fnlwgt': 162298.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 11,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 70.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 23.0,
#   'workclass': 3,
#   'fnlwgt': 211678.0,
#   'education-num': 10.0,
#   'marital-status': 4,
#   'occupation': 6,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 79.0,
#   'workclass': 3,
#   'fnlwgt': 124744.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 2,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 20.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 27.0,
#   'workclass': 3,
#   'fnlwgt': 213921.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 7,
#   'relationship': 3,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 25,
#   'class': 0},
#  {'age': 40.0,
#   'workclass': 3,
#   'fnlwgt': 32214.0,
#   'education-num': 12.0,
#   'marital-status': 2,
#   'occupation': 0,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 67.0,
#   'workclass': 8,
#   'fnlwgt': 212759.0,
#   'education-num': 6.0,
#   'marital-status': 2,
#   'occupation': 14,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 2.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 18.0,
#   'workclass': 3,
#   'fnlwgt': 309634.0,
#   'education-num': 7.0,
#   'marital-status': 4,
#   'occupation': 7,
#   'relationship': 3,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 22.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 31.0,
#   'workclass': 1,
#   'fnlwgt': 125927.0,
#   'education-num': 4.0,
#   'marital-status': 2,
#   'occupation': 4,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 18.0,
#   'workclass': 3,
#   'fnlwgt': 446839.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 11,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 30.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 52.0,
#   'workclass': 3,
#   'fnlwgt': 276515.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 7,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 4,
#   'class': 0},
#  {'age': 46.0,
#   'workclass': 3,
#   'fnlwgt': 51618.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 7,
#   'relationship': 5,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 59.0,
#   'workclass': 3,
#   'fnlwgt': 159937.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 11,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 48.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 44.0,
#   'workclass': 3,
#   'fnlwgt': 343591.0,
#   'education-num': 9.0,
#   'marital-status': 0,
#   'occupation': 2,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 14344.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 53.0,
#   'workclass': 3,
#   'fnlwgt': 346253.0,
#   'education-num': 9.0,
#   'marital-status': 0,
#   'occupation': 11,
#   'relationship': 3,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 35.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 49.0,
#   'workclass': 1,
#   'fnlwgt': 268234.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 10,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 33.0,
#   'workclass': 3,
#   'fnlwgt': 202051.0,
#   'education-num': 14.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 50.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 30.0,
#   'workclass': 3,
#   'fnlwgt': 54334.0,
#   'education-num': 5.0,
#   'marital-status': 4,
#   'occupation': 11,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 43.0,
#   'workclass': 0,
#   'fnlwgt': 410867.0,
#   'education-num': 16.0,
#   'marital-status': 4,
#   'occupation': 9,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 50.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 57.0,
#   'workclass': 3,
#   'fnlwgt': 249977.0,
#   'education-num': 11.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 37.0,
#   'workclass': 3,
#   'fnlwgt': 286730.0,
#   'education-num': 10.0,
#   'marital-status': 0,
#   'occupation': 2,
#   'relationship': 4,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 28.0,
#   'workclass': 3,
#   'fnlwgt': 212563.0,
#   'education-num': 10.0,
#   'marital-status': 0,
#   'occupation': 6,
#   'relationship': 4,
#   'race': 2,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 25.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 30.0,
#   'workclass': 3,
#   'fnlwgt': 117747.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 11,
#   'relationship': 5,
#   'race': 1,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 1573.0,
#   'hours-per-week': 35.0,
#   'native-country': 41,
#   'class': 0},
#  {'age': 34.0,
#   'workclass': 1,
#   'fnlwgt': 226296.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 10,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 29.0,
#   'workclass': 1,
#   'fnlwgt': 115585.0,
#   'education-num': 10.0,
#   'marital-status': 4,
#   'occupation': 5,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 50.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 48.0,
#   'workclass': 5,
#   'fnlwgt': 191277.0,
#   'education-num': 16.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 1902.0,
#   'hours-per-week': 60.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 37.0,
#   'workclass': 3,
#   'fnlwgt': 202683.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 11,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 48.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 48.0,
#   'workclass': 3,
#   'fnlwgt': 171095.0,
#   'education-num': 12.0,
#   'marital-status': 0,
#   'occupation': 3,
#   'relationship': 4,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 8,
#   'class': 0},
#  {'age': 32.0,
#   'workclass': 0,
#   'fnlwgt': 249409.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 7,
#   'relationship': 3,
#   'race': 2,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 76.0,
#   'workclass': 3,
#   'fnlwgt': 124191.0,
#   'education-num': 14.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 44.0,
#   'workclass': 3,
#   'fnlwgt': 198282.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 15024.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 60.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 47.0,
#   'workclass': 5,
#   'fnlwgt': 149116.0,
#   'education-num': 14.0,
#   'marital-status': 4,
#   'occupation': 9,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 50.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 20.0,
#   'workclass': 3,
#   'fnlwgt': 188300.0,
#   'education-num': 10.0,
#   'marital-status': 4,
#   'occupation': 12,
#   'relationship': 3,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 29.0,
#   'workclass': 3,
#   'fnlwgt': 103432.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 2,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 32.0,
#   'workclass': 4,
#   'fnlwgt': 317660.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 7688.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 17.0,
#   'workclass': 8,
#   'fnlwgt': 304873.0,
#   'education-num': 6.0,
#   'marital-status': 4,
#   'occupation': 14,
#   'relationship': 3,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 34095.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 32.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 30.0,
#   'workclass': 3,
#   'fnlwgt': 194901.0,
#   'education-num': 7.0,
#   'marital-status': 4,
#   'occupation': 5,
#   'relationship': 3,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 31.0,
#   'workclass': 1,
#   'fnlwgt': 189265.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 0,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 42.0,
#   'workclass': 3,
#   'fnlwgt': 124692.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 5,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 24.0,
#   'workclass': 3,
#   'fnlwgt': 432376.0,
#   'education-num': 13.0,
#   'marital-status': 4,
#   'occupation': 11,
#   'relationship': 2,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 38.0,
#   'workclass': 3,
#   'fnlwgt': 65324.0,
#   'education-num': 15.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 56.0,
#   'workclass': 5,
#   'fnlwgt': 335605.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 7,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 1887.0,
#   'hours-per-week': 50.0,
#   'native-country': 1,
#   'class': 1},
#  {'age': 28.0,
#   'workclass': 3,
#   'fnlwgt': 377869.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 11,
#   'relationship': 5,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 4064.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 25.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 36.0,
#   'workclass': 3,
#   'fnlwgt': 102864.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 6,
#   'relationship': 3,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 53.0,
#   'workclass': 3,
#   'fnlwgt': 95647.0,
#   'education-num': 5.0,
#   'marital-status': 2,
#   'occupation': 5,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 50.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 56.0,
#   'workclass': 4,
#   'fnlwgt': 303090.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 11,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 50.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 49.0,
#   'workclass': 1,
#   'fnlwgt': 197371.0,
#   'education-num': 11.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 2,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 55.0,
#   'workclass': 3,
#   'fnlwgt': 247552.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 11,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 56.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 22.0,
#   'workclass': 3,
#   'fnlwgt': 102632.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 2,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 41.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 21.0,
#   'workclass': 3,
#   'fnlwgt': 199915.0,
#   'education-num': 10.0,
#   'marital-status': 4,
#   'occupation': 7,
#   'relationship': 3,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 40.0,
#   'workclass': 3,
#   'fnlwgt': 118853.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 60.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 30.0,
#   'workclass': 3,
#   'fnlwgt': 77143.0,
#   'education-num': 13.0,
#   'marital-status': 4,
#   'occupation': 3,
#   'relationship': 3,
#   'race': 2,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 10,
#   'class': 0},
#  {'age': 29.0,
#   'workclass': 6,
#   'fnlwgt': 267989.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 50.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 19.0,
#   'workclass': 3,
#   'fnlwgt': 301606.0,
#   'education-num': 10.0,
#   'marital-status': 4,
#   'occupation': 7,
#   'relationship': 3,
#   'race': 2,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 35.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 47.0,
#   'workclass': 3,
#   'fnlwgt': 287828.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 5,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 20.0,
#   'workclass': 3,
#   'fnlwgt': 111697.0,
#   'education-num': 10.0,
#   'marital-status': 4,
#   'occupation': 0,
#   'relationship': 3,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 1719.0,
#   'hours-per-week': 28.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 31.0,
#   'workclass': 3,
#   'fnlwgt': 114937.0,
#   'education-num': 12.0,
#   'marital-status': 2,
#   'occupation': 0,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 35.0,
#   'workclass': 8,
#   'fnlwgt': 129305.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 14,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 39.0,
#   'workclass': 3,
#   'fnlwgt': 365739.0,
#   'education-num': 10.0,
#   'marital-status': 0,
#   'occupation': 2,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 28.0,
#   'workclass': 3,
#   'fnlwgt': 69621.0,
#   'education-num': 12.0,
#   'marital-status': 4,
#   'occupation': 11,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 60.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 24.0,
#   'workclass': 3,
#   'fnlwgt': 43323.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 7,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 1762.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 38.0,
#   'workclass': 5,
#   'fnlwgt': 120985.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 4386.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 35.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 37.0,
#   'workclass': 3,
#   'fnlwgt': 254202.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 11,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 50.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 46.0,
#   'workclass': 3,
#   'fnlwgt': 146195.0,
#   'education-num': 12.0,
#   'marital-status': 0,
#   'occupation': 12,
#   'relationship': 1,
#   'race': 2,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 36.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 38.0,
#   'workclass': 0,
#   'fnlwgt': 125933.0,
#   'education-num': 14.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 19,
#   'class': 1},
#  {'age': 43.0,
#   'workclass': 5,
#   'fnlwgt': 56920.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 60.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 27.0,
#   'workclass': 3,
#   'fnlwgt': 163127.0,
#   'education-num': 11.0,
#   'marital-status': 2,
#   'occupation': 0,
#   'relationship': 5,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 35.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 20.0,
#   'workclass': 3,
#   'fnlwgt': 34310.0,
#   'education-num': 10.0,
#   'marital-status': 4,
#   'occupation': 11,
#   'relationship': 3,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 20.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 49.0,
#   'workclass': 3,
#   'fnlwgt': 81973.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 1,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 61.0,
#   'workclass': 4,
#   'fnlwgt': 66614.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 27.0,
#   'workclass': 3,
#   'fnlwgt': 232782.0,
#   'education-num': 10.0,
#   'marital-status': 4,
#   'occupation': 11,
#   'relationship': 3,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 19.0,
#   'workclass': 3,
#   'fnlwgt': 316868.0,
#   'education-num': 10.0,
#   'marital-status': 4,
#   'occupation': 7,
#   'relationship': 3,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 30.0,
#   'native-country': 25,
#   'class': 0},
#  {'age': 45.0,
#   'workclass': 3,
#   'fnlwgt': 196584.0,
#   'education-num': 11.0,
#   'marital-status': 4,
#   'occupation': 9,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 1564.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 70.0,
#   'workclass': 3,
#   'fnlwgt': 105376.0,
#   'education-num': 10.0,
#   'marital-status': 4,
#   'occupation': 12,
#   'relationship': 2,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 31.0,
#   'workclass': 3,
#   'fnlwgt': 185814.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 13,
#   'relationship': 4,
#   'race': 2,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 30.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 22.0,
#   'workclass': 3,
#   'fnlwgt': 175374.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 7,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 24.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 36.0,
#   'workclass': 3,
#   'fnlwgt': 108293.0,
#   'education-num': 9.0,
#   'marital-status': 6,
#   'occupation': 7,
#   'relationship': 4,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 24.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 64.0,
#   'workclass': 3,
#   'fnlwgt': 181232.0,
#   'education-num': 7.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 2179.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 43.0,
#   'workclass': 8,
#   'fnlwgt': 174662.0,
#   'education-num': 10.0,
#   'marital-status': 0,
#   'occupation': 14,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 47.0,
#   'workclass': 1,
#   'fnlwgt': 186009.0,
#   'education-num': 10.0,
#   'marital-status': 0,
#   'occupation': 0,
#   'relationship': 4,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 38.0,
#   'native-country': 25,
#   'class': 0},
#  {'age': 34.0,
#   'workclass': 3,
#   'fnlwgt': 198183.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 0,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 33.0,
#   'workclass': 3,
#   'fnlwgt': 163003.0,
#   'education-num': 13.0,
#   'marital-status': 4,
#   'occupation': 3,
#   'relationship': 2,
#   'race': 1,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 29,
#   'class': 0},
#  {'age': 21.0,
#   'workclass': 3,
#   'fnlwgt': 296158.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 2,
#   'relationship': 3,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 35.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 52.0,
#   'workclass': 8,
#   'fnlwgt': 252903.0,
#   'education-num': 9.0,
#   'marital-status': 0,
#   'occupation': 14,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 45.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 48.0,
#   'workclass': 3,
#   'fnlwgt': 187715.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 46.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 23.0,
#   'workclass': 3,
#   'fnlwgt': 214542.0,
#   'education-num': 13.0,
#   'marital-status': 4,
#   'occupation': 5,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 71.0,
#   'workclass': 5,
#   'fnlwgt': 494223.0,
#   'education-num': 10.0,
#   'marital-status': 5,
#   'occupation': 11,
#   'relationship': 4,
#   'race': 2,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 1816.0,
#   'hours-per-week': 2.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 29.0,
#   'workclass': 3,
#   'fnlwgt': 191535.0,
#   'education-num': 9.0,
#   'marital-status': 0,
#   'occupation': 2,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 60.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 42.0,
#   'workclass': 3,
#   'fnlwgt': 228456.0,
#   'education-num': 13.0,
#   'marital-status': 5,
#   'occupation': 7,
#   'relationship': 2,
#   'race': 2,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 50.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 68.0,
#   'workclass': 8,
#   'fnlwgt': 38317.0,
#   'education-num': 2.0,
#   'marital-status': 0,
#   'occupation': 14,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 20.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 25.0,
#   'workclass': 3,
#   'fnlwgt': 252752.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 7,
#   'relationship': 4,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 44.0,
#   'workclass': 4,
#   'fnlwgt': 78374.0,
#   'education-num': 14.0,
#   'marital-status': 0,
#   'occupation': 3,
#   'relationship': 4,
#   'race': 1,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 28.0,
#   'workclass': 3,
#   'fnlwgt': 88419.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 3,
#   'relationship': 1,
#   'race': 1,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 8,
#   'class': 0},
#  {'age': 45.0,
#   'workclass': 5,
#   'fnlwgt': 201080.0,
#   'education-num': 14.0,
#   'marital-status': 2,
#   'occupation': 11,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 36.0,
#   'workclass': 3,
#   'fnlwgt': 207157.0,
#   'education-num': 10.0,
#   'marital-status': 0,
#   'occupation': 7,
#   'relationship': 4,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 25,
#   'class': 0},
#  {'age': 39.0,
#   'workclass': 0,
#   'fnlwgt': 235485.0,
#   'education-num': 12.0,
#   'marital-status': 4,
#   'occupation': 3,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 42.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 46.0,
#   'workclass': 6,
#   'fnlwgt': 102628.0,
#   'education-num': 14.0,
#   'marital-status': 6,
#   'occupation': 10,
#   'relationship': 4,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 18.0,
#   'workclass': 3,
#   'fnlwgt': 25828.0,
#   'education-num': 7.0,
#   'marital-status': 4,
#   'occupation': 5,
#   'relationship': 3,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 16.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 66.0,
#   'workclass': 1,
#   'fnlwgt': 54826.0,
#   'education-num': 11.0,
#   'marital-status': 6,
#   'occupation': 9,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 20.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 27.0,
#   'workclass': 3,
#   'fnlwgt': 124953.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 7,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 1980.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 28.0,
#   'workclass': 6,
#   'fnlwgt': 175325.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 10,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
# ...
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 18.0,
#   'workclass': 3,
#   'fnlwgt': 293227.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 7,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 45.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 20.0,
#   'workclass': 3,
#   'fnlwgt': 241752.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 6,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 54.0,
#   'workclass': 1,
#   'fnlwgt': 166398.0,
#   'education-num': 10.0,
#   'marital-status': 0,
#   'occupation': 3,
#   'relationship': 4,
#   'race': 2,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 35.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 40.0,
#   'workclass': 3,
#   'fnlwgt': 184682.0,
#   'education-num': 10.0,
#   'marital-status': 0,
#   'occupation': 0,
#   'relationship': 4,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 36.0,
#   'workclass': 4,
#   'fnlwgt': 108293.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 5,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 1977.0,
#   'hours-per-week': 45.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 43.0,
#   'workclass': 3,
#   'fnlwgt': 250802.0,
#   'education-num': 10.0,
#   'marital-status': 0,
#   'occupation': 2,
#   'relationship': 4,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 35.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 44.0,
#   'workclass': 5,
#   'fnlwgt': 325159.0,
#   'education-num': 10.0,
#   'marital-status': 0,
#   'occupation': 4,
#   'relationship': 4,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 44.0,
#   'workclass': 6,
#   'fnlwgt': 174675.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 5,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 43.0,
#   'workclass': 3,
#   'fnlwgt': 227065.0,
#   'education-num': 14.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 43.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 51.0,
#   'workclass': 3,
#   'fnlwgt': 269080.0,
#   'education-num': 4.0,
#   'marital-status': 6,
#   'occupation': 7,
#   'relationship': 4,
#   'race': 2,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 18.0,
#   'workclass': 3,
#   'fnlwgt': 177722.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 7,
#   'relationship': 3,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 20.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 51.0,
#   'workclass': 3,
#   'fnlwgt': 133461.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 41.0,
#   'workclass': 3,
#   'fnlwgt': 239683.0,
#   'education-num': 6.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 30.0,
#   'native-country': 41,
#   'class': 0},
#  {'age': 44.0,
#   'workclass': 4,
#   'fnlwgt': 398473.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 11,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 70.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 33.0,
#   'workclass': 1,
#   'fnlwgt': 298785.0,
#   'education-num': 6.0,
#   'marital-status': 0,
#   'occupation': 13,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 33.0,
#   'workclass': 5,
#   'fnlwgt': 123424.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 42.0,
#   'workclass': 3,
#   'fnlwgt': 176286.0,
#   'education-num': 12.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 25.0,
#   'workclass': 3,
#   'fnlwgt': 150062.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 45.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 32.0,
#   'workclass': 3,
#   'fnlwgt': 169240.0,
#   'education-num': 9.0,
#   'marital-status': 0,
#   'occupation': 6,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 38.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 32.0,
#   'workclass': 3,
#   'fnlwgt': 288273.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 70.0,
#   'native-country': 25,
#   'class': 0},
#  {'age': 36.0,
#   'workclass': 3,
#   'fnlwgt': 526968.0,
#   'education-num': 6.0,
#   'marital-status': 0,
#   'occupation': 3,
#   'relationship': 4,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 28.0,
#   'workclass': 3,
#   'fnlwgt': 57066.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 13,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 20.0,
#   'workclass': 3,
#   'fnlwgt': 323573.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 7,
#   'relationship': 3,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 20.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 35.0,
#   'workclass': 4,
#   'fnlwgt': 368825.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 11,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 60.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 55.0,
#   'workclass': 5,
#   'fnlwgt': 189721.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 20.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 48.0,
#   'workclass': 3,
#   'fnlwgt': 164966.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 0,
#   'race': 1,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 18,
#   'class': 1},
#  {'age': 36.0,
#   'workclass': 8,
#   'fnlwgt': 94954.0,
#   'education-num': 11.0,
#   'marital-status': 6,
#   'occupation': 14,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 20.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 34.0,
#   'workclass': 3,
#   'fnlwgt': 202046.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 35.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 28.0,
#   'workclass': 3,
#   'fnlwgt': 161538.0,
#   'education-num': 13.0,
#   'marital-status': 4,
#   'occupation': 12,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 35.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 67.0,
#   'workclass': 3,
#   'fnlwgt': 105252.0,
#   'education-num': 13.0,
#   'marital-status': 6,
#   'occupation': 3,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 2392.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 37.0,
#   'workclass': 3,
#   'fnlwgt': 200153.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 44.0,
#   'workclass': 3,
#   'fnlwgt': 32185.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 13,
#   'relationship': 4,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 70.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 25.0,
#   'workclass': 3,
#   'fnlwgt': 178326.0,
#   'education-num': 10.0,
#   'marital-status': 4,
#   'occupation': 11,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 21.0,
#   'workclass': 3,
#   'fnlwgt': 255957.0,
#   'education-num': 10.0,
#   'marital-status': 4,
#   'occupation': 3,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 4101.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 40.0,
#   'workclass': 6,
#   'fnlwgt': 188693.0,
#   'education-num': 14.0,
#   'marital-status': 2,
#   'occupation': 9,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 35.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 78.0,
#   'workclass': 3,
#   'fnlwgt': 182977.0,
#   'education-num': 9.0,
#   'marital-status': 6,
#   'occupation': 7,
#   'relationship': 1,
#   'race': 2,
#   'sex': 0,
#   'capital-gain': 2964.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 34.0,
#   'workclass': 3,
#   'fnlwgt': 159929.0,
#   'education-num': 9.0,
#   'marital-status': 0,
#   'occupation': 5,
#   'relationship': 3,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 49.0,
#   'workclass': 3,
#   'fnlwgt': 123207.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 0,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 44.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 22.0,
#   'workclass': 3,
#   'fnlwgt': 284317.0,
#   'education-num': 12.0,
#   'marital-status': 4,
#   'occupation': 0,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 23.0,
#   'workclass': 8,
#   'fnlwgt': 184699.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 14,
#   'relationship': 4,
#   'race': 2,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 60.0,
#   'workclass': 5,
#   'fnlwgt': 154474.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 4,
#   'relationship': 4,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 42.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 45.0,
#   'workclass': 1,
#   'fnlwgt': 318280.0,
#   'education-num': 9.0,
#   'marital-status': 6,
#   'occupation': 10,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 63.0,
#   'workclass': 3,
#   'fnlwgt': 254907.0,
#   'education-num': 11.0,
#   'marital-status': 0,
#   'occupation': 7,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 20.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 41.0,
#   'workclass': 3,
#   'fnlwgt': 349221.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 2,
#   'relationship': 3,
#   'race': 2,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 35.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 47.0,
#   'workclass': 3,
#   'fnlwgt': 335973.0,
#   'education-num': 9.0,
#   'marital-status': 0,
#   'occupation': 0,
#   'relationship': 4,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 44.0,
#   'workclass': 3,
#   'fnlwgt': 126701.0,
#   'education-num': 9.0,
#   'marital-status': 0,
#   'occupation': 2,
#   'relationship': 4,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 51.0,
#   'workclass': 3,
#   'fnlwgt': 122159.0,
#   'education-num': 10.0,
#   'marital-status': 6,
#   'occupation': 9,
#   'relationship': 1,
#   'race': 4,
#   'sex': 0,
#   'capital-gain': 3325.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 46.0,
#   'workclass': 3,
#   'fnlwgt': 187370.0,
#   'education-num': 13.0,
#   'marital-status': 4,
#   'occupation': 11,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 1504.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 41.0,
#   'workclass': 3,
#   'fnlwgt': 194636.0,
#   'education-num': 11.0,
#   'marital-status': 2,
#   'occupation': 6,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 50.0,
#   'workclass': 5,
#   'fnlwgt': 124793.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 2,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 30.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 47.0,
#   'workclass': 3,
#   'fnlwgt': 192835.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 0,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 50.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 35.0,
#   'workclass': 3,
#   'fnlwgt': 290226.0,
#   'education-num': 9.0,
#   'marital-status': 4,
#   'occupation': 3,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 45.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 56.0,
#   'workclass': 3,
#   'fnlwgt': 112840.0,
#   'education-num': 9.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 55.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 45.0,
#   'workclass': 3,
#   'fnlwgt': 89325.0,
#   'education-num': 14.0,
#   'marital-status': 0,
#   'occupation': 9,
#   'relationship': 1,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 45.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 48.0,
#   'workclass': 0,
#   'fnlwgt': 33109.0,
#   'education-num': 13.0,
#   'marital-status': 0,
#   'occupation': 3,
#   'relationship': 4,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 0.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 58.0,
#   'native-country': 38,
#   'class': 1},
#  {'age': 40.0,
#   'workclass': 3,
#   'fnlwgt': 82465.0,
#   'education-num': 10.0,
#   'marital-status': 2,
#   'occupation': 6,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 2580.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 40.0,
#   'native-country': 38,
#   'class': 0},
#  {'age': 39.0,
#   'workclass': 4,
#   'fnlwgt': 329980.0,
#   'education-num': 13.0,
#   'marital-status': 2,
#   'occupation': 3,
#   'relationship': 0,
#   'race': 4,
#   'sex': 1,
#   'capital-gain': 15024.0,
#   'capital-loss': 0.0,
#   'hours-per-week': 50.0,
#   'native-country': 38,
#   'class': 1},
#  ...]

# %%
db=client['Assignment']
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Assignment')

# %%
collection=db['Economic_data']

# %%
collection.insert_many(data)

# %%
db2=client['Assignment']

# %%
base=db2['Economic_data']

# %%
print(base)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'Assignment'), 'Economic_data')

# %%
record=base.find_one()

# %%
print(record)
# Out:
# {'_id': ObjectId('636407ce983f1cfa2aac657c'), 'age': 39.0, 'workclass': 5, 'fnlwgt': 77516.0, 'education-num': 13.0, 'marital-status': 4, 'occupation': 0, 'relationship': 1, 'race': 4, 'sex': 1, 'capital-gain': 2174.0, 'capital-loss': 0.0, 'hours-per-week': 40.0, 'native-country': 38, 'class': 0}

# %%
all_record=base.find()
print(all_record)
# Out:
# <pymongo.cursor.Cursor object at 0x000001747FBCD180>

# %%
list_cursor=list(all_record)

# %%
df=pd.DataFrame(list_cursor)
df.head()
# Out:
#                         _id   age  workclass    fnlwgt  education-num  \
# 0  636407ce983f1cfa2aac657c  39.0          5   77516.0           13.0
# 1  636407ce983f1cfa2aac657d  50.0          4   83311.0           13.0
# 2  636407ce983f1cfa2aac657e  38.0          2  215646.0            9.0
# 3  636407ce983f1cfa2aac657f  53.0          2  234721.0            7.0
# 4  636407ce983f1cfa2aac6580  28.0          2  338409.0           13.0
#
#    marital-status  occupation  relationship  race  sex  capital-gain  \
# 0               4           0             1     4    1        2174.0
# 1               2           3             0     4    1           0.0
# 2               0           5             1     4    1           0.0
# 3               2           5             0     2    1           0.0
# 4               2           9             5     2    0           0.0
#
#    capital-loss  hours-per-week  native-country  class
# 0           0.0            40.0              38      0
# 1           0.0            13.0              38      0
# 2           0.0            40.0              38      0
# 3           0.0            40.0              38      0
# 4           0.0            40.0               4      0

# %%
df.to_csv("Data\\retrived_data.csv",index=False)
